# %%
pd.DataFrame(list(track_artist_genre.find()))
# Out:
#                              _id  track_id  \
# 0       6808cffd3b2e7ac928e543a1         2
# 1       6808cffd3b2e7ac928e543a2         3
# 2       6808cffd3b2e7ac928e543a3         5
# 3       6808cffd3b2e7ac928e543a4        10
# 4       6808cffd3b2e7ac928e543a5        20
# ...                          ...       ...
# 106569  6808d00c3b2e7ac928e6e3ea    155316
# 106570  6808d00c3b2e7ac928e6e3eb    155317
# 106571  6808d00c3b2e7ac928e6e3ec    155318
# 106572  6808d00c3b2e7ac928e6e3ed    155319
# 106573  6808d00c3b2e7ac928e6e3ee    155320
#
#                                             title            artist genre_top
# 0                                            Food              AWOL   Hip-Hop
# 1                                    Electric Ave              AWOL   Hip-Hop
# 2                                      This World              AWOL   Hip-Hop
# 3                                         Freeway         Kurt Vile       Pop
# ...

# %%
print(repr(os.getenv("MONGO_URI")))
