# %%
import pandas as pd

from sklearn.metrics.pairwise import cosine_similarity

from sklearn.preprocessing import MinMaxScaler
from pymongo import MongoClient
import os

MONGO_URI = "mongodb+srv://prateeks1110:prateeks.iu@recommendationdata.uywtlek.mongodb.net/?retryWrites=true&w=majority&appName=recommendationData"
client = MongoClient(MONGO_URI)
db = client["FMA_Recommendation"]
recommendation_data = db["recommendation_data"]
track_title_artist = db["track_title_artist"]

# %%
list(track_title_artist.find())
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 list(track_title_artist.find())
#
# File /opt/anaconda3/lib/python3.12/site-packages/pymongo/synchronous/cursor.py:1284, in Cursor.__next__(self)
#    1283 def __next__(self) -> _DocumentType:
# -> 1284     return self.next()
#
# File /opt/anaconda3/lib/python3.12/site-packages/pymongo/synchronous/cursor.py:1260, in Cursor.next(self)
#    1258 if self._empty:
#    1259     raise StopIteration
# -> 1260 if len(self._data) or self._refresh():
#    1261     return self._data.popleft()
#    1262 else:
#
# File /opt/anaconda3/lib/python3.12/site-packages/pymongo/synchronous/cursor.py:1208, in Cursor._refresh(self)
#    1186         raise InvalidOperation(
#    1187             "Passing a 'hint' is required when using the min/max query"
# ...

# %%
print(repr(os.getenv("MONGO_URI")))
