# %%
from extract_song_feature_links import run_url_prob_pipeline
from recommendation_pipeline import new_song_recommendations
# Out:
# Traceback (most recent call last):
#
#   File /opt/anaconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3577 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[5], line 2
#     from recommendation_pipeline import new_song_recommendations
#
#   File ~/Documents/Genre Prediction/Main Data and Notebooks/Final_Notebooks/Optimized Model/Recommendation/recommendation_pipeline.py:53
#     recommendation_list =  track_title_artist["title"].loc[final_recommendations.index] + "| by" + track_title_artist["artist"].loc[final_recommendations.index] + "| genre -" track_title_artist["genre_top"].loc[final_recommendations.index]
#                                                                                                                                                                                ^
# SyntaxError: invalid syntax

# %%
# your_notebook.py (after cleanup)
def run_pipeline():
    get_new_song_genre_prob = run_url_prob_pipeline("https://www.youtube.com/watch?v=sV2t3tW_JTQ&pp=ygUMYmFuayBhY2NvdW50")
    recommendations = new_song_recommendations(get_new_song_genre_prob)
    return recommendations

# %%
recommendations = run_pipeline()

# %%
get_new_song_genre_prob
# Out:
#        Rock  Electronic       Pop   Hip-Hop      Folk
# 0  0.018674    0.081087  0.020478  0.877554  0.002207

# %%
recommendations
# Out:
#        track_id      Rock  Electronic       Pop   Hip-Hop      Folk  interest  \
# 20423     90135  0.014396    0.081954  0.017012  0.884212  0.002427       499
# 15181     63854  0.012927    0.077315  0.022762  0.883064  0.003932       744
# 16635     70208  0.026665    0.081254  0.018679  0.870781  0.002620      8473
# 27810    130456  0.011975    0.084107  0.015618  0.886861  0.001439      2832
# 27686    130156  0.009753    0.084204  0.020548  0.883820  0.001675       364
# 3375      11791  0.010922    0.076924  0.022336  0.887023  0.002794      5694
# 41463     71528  0.015701    0.088998  0.023784  0.869516  0.002002       257
# 14004     60020  0.008980    0.086830  0.021992  0.881091  0.001108       825
# 28868    136469  0.017945    0.071139  0.017675  0.889853  0.003387      5263
# 24535    113408  0.008246    0.084976  0.017344  0.888599  0.000835       722
#
#        favorites  listens  cosine_similarity  final_score
# 20423          1      393           0.999979     0.535748
# 15181          1      375           0.999962     0.537824
# 16635          4     6089           0.999955     0.966644
# 27810          2     2185           0.999950     0.670098
# 27686          2      191           0.999944     0.540687
# 3375           6     1729           0.999942     0.748871
# 41463          0       69           0.999938     0.499969
# 14004          0      333           0.999918     0.520029
# 28868          4     4192           0.999916     0.833020
# 24535          1      509           0.999915     0.544211
