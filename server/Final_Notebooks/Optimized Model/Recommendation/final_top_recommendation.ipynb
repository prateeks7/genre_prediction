# %%
import pandas as pd
import os
import ast

# %%
def load(filepath):

    filename = os.path.basename(filepath)

    if 'features' in filename:
        return pd.read_csv(filepath, index_col=0, header=[0, 1, 2])

    if 'echonest' in filename:
        return pd.read_csv(filepath, index_col=0, header=[0, 1, 2])

    if 'genres' in filename:
        return pd.read_csv(filepath, index_col=0)

    if 'tracks' in filename:
        tracks = pd.read_csv(filepath, index_col=0, header=[0, 1])

        COLUMNS = [('track', 'tags'), ('album', 'tags'), ('artist', 'tags'),
                   ('track', 'genres'), ('track', 'genres_all')]
        for column in COLUMNS:
            tracks[column] = tracks[column].map(ast.literal_eval)

        COLUMNS = [('track', 'date_created'), ('track', 'date_recorded'),
                   ('album', 'date_created'), ('album', 'date_released'),
                   ('artist', 'date_created'), ('artist', 'active_year_begin'),
                   ('artist', 'active_year_end')]
        for column in COLUMNS:
            tracks[column] = pd.to_datetime(tracks[column])

        SUBSETS = ('small', 'medium', 'large')
        try:
            tracks['set', 'subset'] = tracks['set', 'subset'].astype(
                    'category', categories=SUBSETS, ordered=True)
        except (ValueError, TypeError):
            # the categories and ordered arguments were removed in pandas 0.25
            tracks['set', 'subset'] = tracks['set', 'subset'].astype(
                     pd.CategoricalDtype(categories=SUBSETS, ordered=True))

        COLUMNS = [('track', 'genre_top'), ('track', 'license'),
                   ('album', 'type'), ('album', 'information'),
                   ('artist', 'bio')]
        for column in COLUMNS:
            tracks[column] = tracks[column].astype('category')

        return tracks

# %%
tracks = load("../../../fma_metadata/tracks.csv")

# %%
tracks['track']
# Out:
#           bit_rate  comments   composer        date_created date_recorded  \
# track_id
# 2           256000         0        NaN 2008-11-26 01:48:12    2008-11-26
# 3           256000         0        NaN 2008-11-26 01:48:14    2008-11-26
# 5           256000         0        NaN 2008-11-26 01:48:20    2008-11-26
# 10          192000         0  Kurt Vile 2008-11-25 17:49:06    2008-11-26
# 20          256000         0        NaN 2008-11-26 01:48:56    2008-01-01
# ...            ...       ...        ...                 ...           ...
# 155316      320000         0        NaN 2017-03-30 15:23:34           NaT
# 155317      320000         0        NaN 2017-03-30 15:23:36           NaT
# 155318      320000         0        NaN 2017-03-30 15:23:37           NaT
# 155319      320000         0        NaN 2017-03-30 15:23:39           NaT
# 155320      320000         0        NaN 2017-03-30 09:15:36           NaT
#
#           duration  favorites genre_top         genres         genres_all  \
# track_id
# 2              168          2   Hip-Hop           [21]               [21]
# 3              237          1   Hip-Hop           [21]               [21]
# 5              206          6   Hip-Hop           [21]               [21]
# 10             161        178       Pop           [10]               [10]
# 20             311          0       NaN      [76, 103]  [17, 10, 76, 103]
# ...            ...        ...       ...            ...                ...
# 155316         162          1      Rock           [25]           [25, 12]
# 155317         217          1      Rock           [25]           [25, 12]
# 155318         404          2      Rock           [25]           [25, 12]
# 155319         146          0      Rock           [25]           [25, 12]
# 155320         198          1       NaN  [10, 12, 169]   [169, 10, 12, 9]
#
#          information  interest language_code  \
# track_id
# 2                NaN      4656            en
# 3                NaN      1470            en
# 5                NaN      1933            en
# 10               NaN     54881            en
# 20               NaN       978            en
# ...              ...       ...           ...
# 155316           NaN       122           NaN
# 155317           NaN       194           NaN
# 155318           NaN       214           NaN
# 155319           NaN       336           NaN
# 155320           NaN       972           NaN
#
#                                                     license  listens lyricist  \
# track_id
# 2         Attribution-NonCommercial-ShareAlike 3.0 Inter...     1293      NaN
# 3         Attribution-NonCommercial-ShareAlike 3.0 Inter...      514      NaN
# 5         Attribution-NonCommercial-ShareAlike 3.0 Inter...     1151      NaN
# 10        Attribution-NonCommercial-NoDerivatives (aka M...    50135      NaN
# 20        Attribution-NonCommercial-NoDerivatives (aka M...      361      NaN
# ...                                                     ...      ...      ...
# 155316    Creative Commons Attribution-NonCommercial-NoD...      102      NaN
# 155317    Creative Commons Attribution-NonCommercial-NoD...      165      NaN
# 155318    Creative Commons Attribution-NonCommercial-NoD...      168      NaN
# 155319    Creative Commons Attribution-NonCommercial-NoD...      294      NaN
# 155320                            Attribution-NonCommercial      705      NaN
#
#           number publisher                                               tags  \
# track_id
# 2              3       NaN                                                 []
# 3              4       NaN                                                 []
# 5              6       NaN                                                 []
# 10             1       NaN                                                 []
# 20             3       NaN                                                 []
# ...          ...       ...                                                ...
# 155316         3       NaN                                                 []
# 155317         4       NaN                                                 []
# 155318         6       NaN                                                 []
# 155319         5       NaN                                                 []
# 155320         7       NaN  [ballad, epic, rockabilly, curse, hex, hard ro...
#
#                                               title
# track_id
# 2                                              Food
# 3                                      Electric Ave
# 5                                        This World
# 10                                          Freeway
# 20                                  Spiritual Level
# ...                                             ...
# 155316                                    The Auger
# 155317                              Let's Skin Ruby
# 155318           My House Smells Like Kim Deal/Pulp
# 155319                      The Man With Two Mouths
# 155320    Another Trick Up My Sleeve (Instrumental)
#
# [106574 rows x 20 columns]

# %%
classified_top_genre = pd.read_csv("top_genre_prob_by_optimized_classification.csv",index_col=[0])

# %%
classified_top_genre
# Out:
#               Rock  Electronic       Pop   Hip-Hop      Folk
# track_id
# 2         0.003639    0.010459  0.009752  0.974635  0.001515
# 3         0.045891    0.044842  0.106042  0.785288  0.017937
# 5         0.005435    0.020162  0.036643  0.930348  0.007411
# 10        0.162003    0.133598  0.663075  0.021528  0.019796
# 134       0.030814    0.061230  0.042618  0.854423  0.010914
# ...            ...         ...       ...       ...       ...
# 155315    0.973578    0.005273  0.014719  0.001956  0.004475
# 155316    0.995178    0.000831  0.001596  0.000050  0.002345
# 155317    0.970530    0.010954  0.010181  0.000799  0.007536
# 155318    0.994592    0.002137  0.002263  0.000290  0.000719
# 155319    0.974155    0.012586  0.009682  0.001975  0.001603
#
# [32239 rows x 5 columns]

# %%
classified_remaining_genre = pd.read_csv("../reclassified_remaining_genres.csv",index_col=[0])

# %%
all_genre_probs = pd.concat([classified_top_genre,classified_remaining_genre])

# %%
track_recommendation_data = pd.DataFrame(tracks['track'][["interest","favorites","listens"]])

# %%
track_recommendation_data
# Out:
#           interest  favorites  listens
# track_id
# 2             4656          2     1293
# 3             1470          1      514
# 5             1933          6     1151
# 10           54881        178    50135
# 20             978          0      361
# ...            ...        ...      ...
# 155316         122          1      102
# 155317         194          1      165
# 155318         214          2      168
# 155319         336          0      294
# 155320         972          1      705
#
# [106574 rows x 3 columns]

# %%
recommendation_data = classified_top_genre.merge(track_recommendation_data,left_index=True,right_index=True)

# %%
# recommendation_data.to_csv("base_recommendation_data_logistic.csv")

# %%
recommendation_data
# Out:
#               Rock  Electronic       Pop   Hip-Hop      Folk  interest  \
# track_id
# 2         0.003639    0.010459  0.009752  0.974635  0.001515      4656
# 3         0.045891    0.044842  0.106042  0.785288  0.017937      1470
# 5         0.005435    0.020162  0.036643  0.930348  0.007411      1933
# 10        0.162003    0.133598  0.663075  0.021528  0.019796     54881
# 134       0.030814    0.061230  0.042618  0.854423  0.010914      1126
# ...            ...         ...       ...       ...       ...       ...
# 155315    0.973578    0.005273  0.014719  0.001956  0.004475       153
# 155316    0.995178    0.000831  0.001596  0.000050  0.002345       122
# 155317    0.970530    0.010954  0.010181  0.000799  0.007536       194
# 155318    0.994592    0.002137  0.002263  0.000290  0.000719       214
# 155319    0.974155    0.012586  0.009682  0.001975  0.001603       336
#
#           favorites  listens  cosine_similarity
# track_id
# 2                 2     1293           0.999357
# 3                 1      514           0.990057
# 5                 6     1151           0.999056
# 10              178    50135           0.045363
# 134               3      943           0.998176
# ...             ...      ...                ...
# 155315            1      128           0.010702
# 155316            1      102           0.008482
# 155317            1      165           0.009772
# 155318            2      168           0.008783
# 155319            0      294           0.011039
#
# [32239 rows x 9 columns]

# %%
recomendation_data = pd.read_csv("basic_recommendation_data_logistic_new.csv",index_col="track_id")

# %%
recomendation_data
# Out:
#               Rock  Electronic       Pop   Hip-Hop      Folk  interest  \
# track_id
# 2         0.286368    0.016376  0.236220  0.124459  0.336576      4656
# 3         0.317199    0.011163  0.440916  0.112801  0.117921      1470
# 5         0.550803    0.035311  0.181760  0.102528  0.129597      1933
# 10        0.061826    0.014149  0.035781  0.052516  0.835728     54881
# 134       0.264930    0.040877  0.170940  0.133790  0.389463      1126
# ...            ...         ...       ...       ...       ...       ...
# 155315    0.101480    0.056093  0.038208  0.052576  0.751643       153
# 155316    0.062029    0.079743  0.033572  0.039813  0.784843       122
# 155317    0.306270    0.099794  0.073537  0.114412  0.405988       194
# 155318    0.116667    0.054354  0.053267  0.055791  0.719921       214
# 155319    0.100324    0.068367  0.042999  0.045316  0.742994       336
#
#           favorites  listens
# track_id
# 2                 2     1293
# 3                 1      514
# 5                 6     1151
# 10              178    50135
# 134               3      943
# ...             ...      ...
# 155315            1      128
# 155316            1      102
# 155317            1      165
# 155318            2      168
# 155319            0      294
#
# [32241 rows x 8 columns]

# %%
bank_acc_prob = pd.read_csv("bank_acc_bad_prob_logistic.csv",index_col=[0])

# %%
bank_acc_prob
# Out:
#           0         1         2         3         4
# 0  0.322686  0.085995  0.198854  0.122059  0.270405

# %%
recomendation_data
# Out:
#               Rock  Electronic       Pop   Hip-Hop      Folk  interest  \
# track_id
# 2         0.286368    0.016376  0.236220  0.124459  0.336576      4656
# 3         0.317199    0.011163  0.440916  0.112801  0.117921      1470
# 5         0.550803    0.035311  0.181760  0.102528  0.129597      1933
# 10        0.061826    0.014149  0.035781  0.052516  0.835728     54881
# 134       0.264930    0.040877  0.170940  0.133790  0.389463      1126
# ...            ...         ...       ...       ...       ...       ...
# 155315    0.101480    0.056093  0.038208  0.052576  0.751643       153
# 155316    0.062029    0.079743  0.033572  0.039813  0.784843       122
# 155317    0.306270    0.099794  0.073537  0.114412  0.405988       194
# 155318    0.116667    0.054354  0.053267  0.055791  0.719921       214
# 155319    0.100324    0.068367  0.042999  0.045316  0.742994       336
#
#           favorites  listens
# track_id
# 2                 2     1293
# 3                 1      514
# 5                 6     1151
# 10              178    50135
# 134               3      943
# ...             ...      ...
# 155315            1      128
# 155316            1      102
# 155317            1      165
# 155318            2      168
# 155319            0      294
#
# [32241 rows x 8 columns]

# %%
from sklearn.metrics.pairwise import cosine_similarity

new_song_similarities = cosine_similarity(bank_acc_prob,recomendation_data[recomendation_data.columns[:5]])
recomendation_data["cosine_similarity"] = new_song_similarities[0]

# %%
recomendation_data
# Out:
#               Rock  Electronic       Pop   Hip-Hop      Folk  interest  \
# track_id
# 2         0.286368    0.016376  0.236220  0.124459  0.336576      4656
# 3         0.317199    0.011163  0.440916  0.112801  0.117921      1470
# 5         0.550803    0.035311  0.181760  0.102528  0.129597      1933
# 10        0.061826    0.014149  0.035781  0.052516  0.835728     54881
# 134       0.264930    0.040877  0.170940  0.133790  0.389463      1126
# ...            ...         ...       ...       ...       ...       ...
# 155315    0.101480    0.056093  0.038208  0.052576  0.751643       153
# 155316    0.062029    0.079743  0.033572  0.039813  0.784843       122
# 155317    0.306270    0.099794  0.073537  0.114412  0.405988       194
# 155318    0.116667    0.054354  0.053267  0.055791  0.719921       214
# 155319    0.100324    0.068367  0.042999  0.045316  0.742994       336
#
#           favorites  listens  cosine_similarity
# track_id
# 2                 2     1293           0.977861
# 3                 1      514           0.853205
# 5                 6     1151           0.895323
# 10              178    50135           0.634270
# 134               3      943           0.961703
# ...             ...      ...                ...
# 155315            1      128           0.682786
# 155316            1      102           0.646365
# 155317            1      165           0.938143
# 155318            2      168           0.707479
# 155319            0      294           0.685596
#
# [32241 rows x 9 columns]

# %%
top_recommendations = recomendation_data.nlargest(10, "cosine_similarity").copy()

# %%
top_recommendations
# Out:
#               Rock  Electronic       Pop   Hip-Hop      Folk  interest  \
# track_id
# 1715      0.319068    0.100115  0.179326  0.128773  0.272718       745
# 36720     0.311592    0.102912  0.206564  0.103824  0.275107       952
# 679       0.314719    0.084966  0.202810  0.104597  0.292907      1104
# 678       0.319833    0.092378  0.192345  0.102934  0.292510       693
# 32661     0.325471    0.076648  0.201400  0.102308  0.294173       314
# 129696    0.326548    0.085713  0.222761  0.104147  0.260832      1349
# 54877     0.315410    0.069659  0.199862  0.115678  0.299391      1862
# 99089     0.337220    0.062987  0.192335  0.114106  0.293351       864
# 84609     0.323938    0.106623  0.172096  0.124870  0.272474       171
# 17369     0.339687    0.089950  0.175330  0.109359  0.285673       143
#
#           favorites  listens  cosine_similarity
# track_id
# 1715              0      262           0.998679
# 36720             2      727           0.998281
# 679               0      315           0.998210
# 678               0       91           0.998094
# 32661             2      199           0.998058
# 129696            2     1180           0.997950
# 54877             3      419           0.997672
# 99089             0      723           0.997657
# 84609             1      143           0.997592
# 17369             0       95           0.997587

# %%
top_recommendations["cosine_similarity"].mean()
# Out:
# 0.9979779318928858

# %%
normalized_features = pd.DataFrame(columns=["normalized_listens","normalized_favorites","normalized_interest"],index=top_recommendations.index)

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
normalized_features['normalized_listens'] = scaler.fit_transform(top_recommendations[['listens']])[:, 0]
normalized_features['normalized_favorites'] = scaler.fit_transform(top_recommendations[['favorites']])[:, 0]
normalized_features['normalized_interest'] = scaler.fit_transform(top_recommendations[['interest']])[:, 0]

# %%
normalized_features
# Out:
#           normalized_listens  normalized_favorites  normalized_interest
# track_id
# 1715                0.157025              0.000000             0.350204
# 36720               0.584022              0.666667             0.470622
# 679                 0.205693              0.000000             0.559046
# 678                 0.000000              0.000000             0.319953
# 32661               0.099174              0.666667             0.099476
# 129696              1.000000              0.666667             0.701571
# 54877               0.301194              1.000000             1.000000
# 99089               0.580349              0.000000             0.419430
# 84609               0.047750              0.333333             0.016289
# 17369               0.003673              0.000000             0.000000

# %%
top_recommendations["final_score"] = (0.5 * top_recommendations["cosine_similarity"]
                + 0.3 * normalized_features["normalized_listens"]
               + 0.1 * normalized_features["normalized_favorites"]
               + 0.1 * normalized_features["normalized_interest"])

# %%
top_recommendations
# Out:
#               Rock  Electronic       Pop   Hip-Hop      Folk  interest  \
# track_id
# 1715      0.319068    0.100115  0.179326  0.128773  0.272718       745
# 36720     0.311592    0.102912  0.206564  0.103824  0.275107       952
# 679       0.314719    0.084966  0.202810  0.104597  0.292907      1104
# 678       0.319833    0.092378  0.192345  0.102934  0.292510       693
# 32661     0.325471    0.076648  0.201400  0.102308  0.294173       314
# 129696    0.326548    0.085713  0.222761  0.104147  0.260832      1349
# 54877     0.315410    0.069659  0.199862  0.115678  0.299391      1862
# 99089     0.337220    0.062987  0.192335  0.114106  0.293351       864
# 84609     0.323938    0.106623  0.172096  0.124870  0.272474       171
# 17369     0.339687    0.089950  0.175330  0.109359  0.285673       143
#
#           favorites  listens  cosine_similarity  final_score
# track_id
# 1715              0      262           0.998679     0.581467
# 36720             2      727           0.998281     0.788076
# 679               0      315           0.998210     0.616718
# 678               0       91           0.998094     0.531042
# 32661             2      199           0.998058     0.605396
# 129696            2     1180           0.997950     0.935799
# 54877             3      419           0.997672     0.789194
# 99089             0      723           0.997657     0.714876
# 84609             1      143           0.997592     0.548083
# 17369             0       95           0.997587     0.499895

# %%
top_recommendations["final_score"].mean()
# Out:
# 0.6610546008773801

# %%
final_recommendations = top_recommendations.sort_values("final_score", ascending=False)

# %%
final_recommendations.index
# Out:
# Index([129696, 54877, 36720, 99089, 679, 32661, 1715, 84609, 678, 17369], dtype='int64', name='track_id')

# %%
tracks['track'].loc[final_recommendations.index]
# Out:
#           bit_rate  comments composer        date_created date_recorded  \
# track_id
# 129696      256256         0      NaN 2015-12-22 15:15:11           NaT
# 54877       160000         1      NaN 2011-10-18 12:02:16           NaT
# 36720        64000         0      NaN 2010-10-05 03:50:07           NaT
# 99089       320000         0      NaN 2014-02-13 12:07:00           NaT
# 679         256000         0      NaN 2008-11-26 02:12:08    2008-11-26
# 32661       192000         0      NaN 2010-07-09 12:31:20           NaT
# 1715        256000         0      NaN 2008-11-26 03:04:01           NaT
# 84609       192000         0      NaN 2013-05-22 16:30:23           NaT
# 678         256000         0      NaN 2008-11-26 02:12:04    2007-01-01
# 17369       320000         0      NaN 2009-07-27 00:05:31           NaT
#
#           duration  favorites   genre_top      genres      genres_all  \
# track_id
# 129696         145          2        Folk   [17, 103]       [17, 103]
# 54877          257          3  Electronic  [181, 236]  [236, 181, 15]
# 36720          170          2        Rock   [31, 314]   [314, 12, 31]
# 99089          100          0     Hip-Hop        [21]            [21]
# 679            340          0     Hip-Hop        [21]            [21]
# 32661          209          2     Hip-Hop        [21]            [21]
# 1715           111          0        Rock        [12]            [12]
# 84609          395          1         Pop       [362]       [362, 10]
# 678            341          0     Hip-Hop        [21]            [21]
# 17369          127          0        Rock        [12]            [12]
#
#          information  interest language_code  \
# track_id
# 129696           NaN      1349           NaN
# 54877            NaN      1862           NaN
# 36720            NaN       952           NaN
# 99089            NaN       864           NaN
# 679              NaN      1104            en
# 32661            NaN       314           NaN
# 1715             NaN       745            en
# 84609            NaN       171           NaN
# 678              NaN       693            en
# 17369            NaN       143            en
#
#                                                     license  listens lyricist  \
# track_id
# 129696    Creative Commons Attribution-NonCommercial-NoD...     1180      NaN
# 54877     Attribution-Noncommercial-Share Alike 3.0 Unit...      419      NaN
# 36720     Attribution-NonCommercial-NoDerivatives (aka M...      727      NaN
# 99089     Creative Commons Attribution-NonCommercial-NoD...      723      NaN
# 679       Attribution-NonCommercial-ShareAlike 3.0 Inter...      315      NaN
# 32661     Attribution-NonCommercial-NoDerivatives (aka M...      199      NaN
# 1715      Attribution-Noncommercial-Share Alike 3.0 Unit...      262      NaN
# 84609     Attribution-Noncommercial-No Derivative Works ...      143      NaN
# 678       Attribution-NonCommercial-ShareAlike 3.0 Inter...       91      NaN
# 17369     Attribution-NonCommercial-NoDerivatives (aka M...       95      NaN
#
#           number publisher                                     tags  \
# track_id
# 129696         3       NaN                                       []
# 54877          5       NaN                                   [acid]
# 36720         14       NaN                      [horror, halloween]
# 99089         16       NaN                                       []
# 679            6       NaN                                       []
# 32661          4       NaN                                       []
# 1715           6       NaN                                       []
# 84609          5       NaN     [earth-enemy, synth pop, electronic]
# 678            6       NaN                                       []
# 17369          2       NaN  [clinical archives, rock, experimental]
#
#                                        title
# track_id
# 129696                                  Laws
# 54877                                 Isered
# 36720                                    RAW
# 99089                      Give It to the DJ
# 679                          Change Thoughts
# 32661     Cocaine Dreamers feat. Shane Laden
# 1715                      Hell Yeah, Fuck Em
# 84609                      Hills and Troughs
# 678                          Change Thoughts
# 17369                    Feast on your flesh

# %%
track_name = tracks['track'].loc[final_recommendations.index]["title"]

# %%
artist_name = tracks['artist'].loc[final_recommendations.index]["name"]

# %%
genre_name = tracks['track'].loc[final_recommendations.index]["genre_top"]

# %%
track_name
# Out:
# track_id
# 129696                                  Laws
# 54877                                 Isered
# 36720                                    RAW
# 99089                      Give It to the DJ
# 679                          Change Thoughts
# 32661     Cocaine Dreamers feat. Shane Laden
# 1715                      Hell Yeah, Fuck Em
# 84609                      Hills and Troughs
# 678                          Change Thoughts
# 17369                    Feast on your flesh
# Name: title, dtype: object

# %%
artist_name
# Out:
# track_id
# 129696         Derek Clegg
# 54877          Global Goon
# 36720       Art Of Empathy
# 99089     The Impossebulls
# 679                Fanatic
# 32661        Fidel Cutstro
# 1715            Stress Ape
# 84609          EARTH-ENEMY
# 678                Fanatic
# 17369           Zack Kouns
# Name: name, dtype: object

# %%
genre_name
# Out:
# track_id
# 129696          Folk
# 54877     Electronic
# 36720           Rock
# 99089        Hip-Hop
# 679          Hip-Hop
# 32661        Hip-Hop
# 1715            Rock
# 84609            Pop
# 678          Hip-Hop
# 17369           Rock
# Name: genre_top, dtype: category
# Categories (16, object): ['Blues', 'Classical', 'Country', 'Easy Listening', ..., 'Pop', 'Rock', 'Soul-RnB', 'Spoken']
