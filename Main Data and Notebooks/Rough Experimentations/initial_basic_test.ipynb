# %%
import pandas as pd

# %%
data = pd.read_csv("initial_basic_test.csv")

# %%
data
# Out:
#        track_id  genre_top       min_1         min_2       min_3      min_4  \
# 0             2         21 -504.891144 -1.421085e-14 -115.315613 -51.569004
# 1             3         21 -546.268188 -1.851665e+01  -85.012314 -12.548506
# 2             5         21 -528.702759 -6.228398e+01  -87.205124 -24.319845
# 3            10         10 -537.587097  5.151435e-14 -130.033524 -50.578659
# 4           134         21 -498.915253 -9.427860e-01 -153.539062 -90.334747
# ...         ...        ...         ...           ...         ...        ...
# 49593    155315         12 -544.398132 -4.263256e-14 -105.245056 -43.628036
# 49594    155316         12 -549.671082 -1.421085e-14  -88.110970 -31.289186
# 49595    155317         12 -535.016968 -2.309264e-14  -81.964645 -54.055511
# 49596    155318         12 -539.652710 -2.309264e-14  -99.632660 -67.046196
# 49597    155319         12 -536.961426 -3.907985e-14 -103.328140 -51.425495
#
#            min_5      min_6      min_7      min_8  ...  kurtosis_11  \
# 0     -97.879890 -41.524628 -61.748718 -39.678986  ...    -0.029920
# 1     -87.048355 -26.988558 -61.851612 -33.421520  ...     0.511647
# 2     -74.060310 -30.447651 -59.320251 -33.444458  ...     0.096892
# 3     -45.113949 -45.514446 -44.849060 -43.018734  ...    -0.051230
# 4     -67.671829 -70.446243 -56.525692 -42.223763  ...     0.390185
# ...          ...        ...        ...        ...  ...          ...
# 49593 -49.708946 -46.375156 -49.417274 -46.293465  ...     1.288644
# 49594 -52.357323 -34.206707 -38.805759 -23.110428  ...     0.471171
# 49595 -33.997089 -32.789070 -37.552673 -28.776550  ...     1.056984
# 49596 -67.550385 -62.373932 -42.689365 -51.318504  ...     0.109289
# 49597 -58.588928 -45.654152 -36.001179 -26.111862  ...     0.180174
#
#        kurtosis_12  kurtosis_13  kurtosis_14  kurtosis_15  kurtosis_16  \
# 0         0.430621    -0.225081    -0.303092    -0.190764    -0.052871
# 1         0.374576     0.214880     0.101417     0.480927     0.269853
# 2        -0.248479     0.159848     0.637849     0.192881     0.286125
# 3        -0.189193     0.024108     0.111374     0.178489    -0.124275
# 4         0.678185     0.902300     0.311145     0.381535     0.551284
# ...            ...          ...          ...          ...          ...
# 49593     0.836856     2.961873     0.828493     0.187169     1.240297
# 49594     0.507091     0.326060     1.325684     0.894563     0.271580
# 49595     0.999656     1.382273     1.653984     1.213623     0.789652
# 49596     0.113911     0.544816     0.759106     0.955861     0.725221
# 49597     0.638844     1.308893     0.845607     0.710383     0.881930
#
#        kurtosis_17  kurtosis_18  kurtosis_19  kurtosis_20
# 0        -0.151794    -0.000590     0.075492     0.002595
# 1         0.113057     0.094816     0.313537     0.055046
# 2        -0.066113     0.363365     0.614379     0.131038
# 3        -0.031861    -0.154391     0.105716     0.043984
# 4         0.617928     0.232897     0.561238     0.369535
# ...            ...          ...          ...          ...
# 49593     1.767271     1.634887     0.422319     0.251240
# 49594     0.396176     0.976939     0.419615     0.256208
# 49595     1.238838     0.612640     0.790082     0.461009
# 49596     0.241678     0.443703     0.404715     0.186785
# 49597     0.334009     0.543394     0.626632     0.056745
#
# [49598 rows x 142 columns]

# %%
X = data.drop(["track_id","genre_top"],axis=1)
y = data["genre_top"]

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, mean_squared_error, r2_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
# from imblearn.under_sampling import RandomUnderSampler

# rus = RandomUnderSampler(sampling_strategy='auto', random_state=42)
# X_train_resampled, y_train_resampled = rus.fit_resample(X_train, y_train)

# %%
model = RandomForestClassifier(n_estimators=100)

# %%
X
# Out:
#             min_1         min_2       min_3      min_4      min_5      min_6  \
# 0     -504.891144 -1.421085e-14 -115.315613 -51.569004 -97.879890 -41.524628
# 1     -546.268188 -1.851665e+01  -85.012314 -12.548506 -87.048355 -26.988558
# 2     -528.702759 -6.228398e+01  -87.205124 -24.319845 -74.060310 -30.447651
# 3     -537.587097  5.151435e-14 -130.033524 -50.578659 -45.113949 -45.514446
# 4     -498.915253 -9.427860e-01 -153.539062 -90.334747 -67.671829 -70.446243
# ...           ...           ...         ...        ...        ...        ...
# 49593 -544.398132 -4.263256e-14 -105.245056 -43.628036 -49.708946 -46.375156
# 49594 -549.671082 -1.421085e-14  -88.110970 -31.289186 -52.357323 -34.206707
# 49595 -535.016968 -2.309264e-14  -81.964645 -54.055511 -33.997089 -32.789070
# 49596 -539.652710 -2.309264e-14  -99.632660 -67.046196 -67.550385 -62.373932
# 49597 -536.961426 -3.907985e-14 -103.328140 -51.425495 -58.588928 -45.654152
#
#            min_7      min_8      min_9     min_10  ...  kurtosis_11  \
# 0     -61.748718 -39.678986 -54.222973 -42.562126  ...    -0.029920
# 1     -61.851612 -33.421520 -47.009068 -31.347380  ...     0.511647
# 2     -59.320251 -33.444458 -38.407055 -26.083885  ...     0.096892
# 3     -44.849060 -43.018734 -44.329350 -40.170555  ...    -0.051230
# 4     -56.525692 -42.223763 -40.045094 -34.741753  ...     0.390185
# ...          ...        ...        ...        ...  ...          ...
# 49593 -49.417274 -46.293465 -25.527483 -42.347538  ...     1.288644
# 49594 -38.805759 -23.110428 -33.603550 -30.156258  ...     0.471171
# 49595 -37.552673 -28.776550 -28.386343 -27.148310  ...     1.056984
# 49596 -42.689365 -51.318504 -40.529449 -34.131432  ...     0.109289
# 49597 -36.001179 -26.111862 -27.589993 -31.411812  ...     0.180174
#
#        kurtosis_12  kurtosis_13  kurtosis_14  kurtosis_15  kurtosis_16  \
# 0         0.430621    -0.225081    -0.303092    -0.190764    -0.052871
# 1         0.374576     0.214880     0.101417     0.480927     0.269853
# 2        -0.248479     0.159848     0.637849     0.192881     0.286125
# 3        -0.189193     0.024108     0.111374     0.178489    -0.124275
# 4         0.678185     0.902300     0.311145     0.381535     0.551284
# ...            ...          ...          ...          ...          ...
# 49593     0.836856     2.961873     0.828493     0.187169     1.240297
# 49594     0.507091     0.326060     1.325684     0.894563     0.271580
# 49595     0.999656     1.382273     1.653984     1.213623     0.789652
# 49596     0.113911     0.544816     0.759106     0.955861     0.725221
# 49597     0.638844     1.308893     0.845607     0.710383     0.881930
#
#        kurtosis_17  kurtosis_18  kurtosis_19  kurtosis_20
# 0        -0.151794    -0.000590     0.075492     0.002595
# 1         0.113057     0.094816     0.313537     0.055046
# 2        -0.066113     0.363365     0.614379     0.131038
# 3        -0.031861    -0.154391     0.105716     0.043984
# 4         0.617928     0.232897     0.561238     0.369535
# ...            ...          ...          ...          ...
# 49593     1.767271     1.634887     0.422319     0.251240
# 49594     0.396176     0.976939     0.419615     0.256208
# 49595     1.238838     0.612640     0.790082     0.461009
# 49596     0.241678     0.443703     0.404715     0.186785
# 49597     0.334009     0.543394     0.626632     0.056745
#
# [49598 rows x 140 columns]

# %%
y

# %%
model.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = model.predict(X_test)

# %%
y_pred = pd.DataFrame(y_pred)

# %%
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred,average='micro')
recall = recall_score(y_test, y_pred,average='micro')
f1 = f1_score(y_test, y_pred,average='micro')
confusion = confusion_matrix(y_test, y_pred)
mean_squared_error = mean_squared_error(y_test, y_pred)
r2_score = r2_score(y_test, y_pred)


# Print metricsµ
print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1-score: {f1}")
print(f"Confusion Matrix:\n{confusion}")
print(f"Mean Squared Error: {mean_squared_error}")
print(f"R2 Score: {r2_score}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[214], line 6
#       4 f1 = f1_score(y_test, y_pred,average='micro')
#       5 confusion = confusion_matrix(y_test, y_pred)
# ----> 6 mean_squared_error = mean_squared_error(y_test, y_pred)
#       7 r2_score = r2_score(y_test, y_pred)
#      10 # Print metricsµ
#
# TypeError: 'numpy.float64' object is not callable

# %%
gd = pd.read_csv("mona_lisa.csv",index_col=[0],header=[0,1,2])

# %%
gd['mfcc'].columns
# Out:
# MultiIndex([('kurtosis', '01'),
#             ('kurtosis', '02'),
#             ('kurtosis', '03'),
#             ('kurtosis', '04'),
#             ('kurtosis', '05'),
#             ('kurtosis', '06'),
#             ('kurtosis', '07'),
#             ('kurtosis', '08'),
#             ('kurtosis', '09'),
#             ('kurtosis', '10'),
#             ...
#             (     'std', '11'),
#             (     'std', '12'),
#             (     'std', '13'),
#             (     'std', '14'),
#             (     'std', '15'),
#             (     'std', '16'),
#             (     'std', '17'),
#             (     'std', '18'),
#             (     'std', '19'),
#             (     'std', '20')],
#            names=['statistics', 'number'], length=140)

# %%
kurtosisColumn = ["kurtosis_1","kurtosis_2","kurtosis_3","kurtosis_4","kurtosis_5","kurtosis_6","kurtosis_7","kurtosis_8","kurtosis_9","kurtosis_10","kurtosis_11","kurtosis_12","kurtosis_13","kurtosis_14","kurtosis_15","kurtosis_16","kurtosis_17","kurtosis_18","kurtosis_19","kurtosis_20"]
minColumn = ["min_1","min_2","min_3","min_4","min_5","min_6","min_7","min_8","min_9","min_10","min_11","min_12","min_13","min_14","min_15","min_16","min_17","min_18","min_19","min_20"]
maxColumn = ["max_1","max_2","max_3","max_4","max_5","max_6","max_7","max_8","max_9","max_10","max_11","max_12","max_13","max_14","max_15","max_16","max_17","max_18","max_19","max_20"]
stdColumn = ["std_1","std_2","std_3","std_4","std_5","std_6","std_7","std_8","std_9","std_10","std_11","std_12","std_13","std_14","std_15","std_16","std_17","std_18","std_19","std_20"]
meanColumn = ["mean_1","mean_2","mean_3","mean_4","mean_5","mean_6","mean_7","mean_8","mean_9","mean_10","mean_11","mean_12","mean_13","mean_14","mean_15","mean_16","mean_17","mean_18","mean_19","mean_20"]
medianColumn = ["median_1","median_2","median_3","median_4","median_5","median_6","median_7","median_8","median_9","median_10","median_11","median_12","median_13","median_14","median_15","median_16","median_17","median_18","median_19","median_20"]
skewColumn = ["skew_1","skew_2","skew_3","skew_4","skew_5","skew_6","skew_7","skew_8","skew_9","skew_10","skew_11","skew_12","skew_13","skew_14","skew_15","skew_16","skew_17","skew_18","skew_19","skew_20"]

# %%
kurtosisMfcc = gd['mfcc','kurtosis'].set_axis(kurtosisColumn, axis=1)
minMfcc = gd['mfcc','min'].set_axis(minColumn, axis=1)
maxMfcc = gd['mfcc','max'].set_axis(maxColumn, axis=1)
stdMfcc = gd['mfcc','std'].set_axis(stdColumn, axis=1)
meanMfcc = gd['mfcc','mean'].set_axis(meanColumn, axis=1)
medianMfcc = gd['mfcc','median'].set_axis(medianColumn, axis=1)
skewMfcc = gd['mfcc','skew'].set_axis(skewColumn, axis=1)
# Out:
# /var/folders/gv/571nb6gs4h58lv0gw0__gy280000gn/T/ipykernel_24877/1870495744.py:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   kurtosisMfcc = gd['mfcc','kurtosis'].set_axis(kurtosisColumn, axis=1)
# /var/folders/gv/571nb6gs4h58lv0gw0__gy280000gn/T/ipykernel_24877/1870495744.py:2: PerformanceWarning: indexing past lexsort depth may impact performance.
#   minMfcc = gd['mfcc','min'].set_axis(minColumn, axis=1)
# /var/folders/gv/571nb6gs4h58lv0gw0__gy280000gn/T/ipykernel_24877/1870495744.py:3: PerformanceWarning: indexing past lexsort depth may impact performance.
#   maxMfcc = gd['mfcc','max'].set_axis(maxColumn, axis=1)
# /var/folders/gv/571nb6gs4h58lv0gw0__gy280000gn/T/ipykernel_24877/1870495744.py:4: PerformanceWarning: indexing past lexsort depth may impact performance.
#   stdMfcc = gd['mfcc','std'].set_axis(stdColumn, axis=1)
# /var/folders/gv/571nb6gs4h58lv0gw0__gy280000gn/T/ipykernel_24877/1870495744.py:5: PerformanceWarning: indexing past lexsort depth may impact performance.
#   meanMfcc = gd['mfcc','mean'].set_axis(meanColumn, axis=1)
# /var/folders/gv/571nb6gs4h58lv0gw0__gy280000gn/T/ipykernel_24877/1870495744.py:6: PerformanceWarning: indexing past lexsort depth may impact performance.
#   medianMfcc = gd['mfcc','median'].set_axis(medianColumn, axis=1)
# /var/folders/gv/571nb6gs4h58lv0gw0__gy280000gn/T/ipykernel_24877/1870495744.py:7: PerformanceWarning: indexing past lexsort depth may impact performance.
#   skewMfcc = gd['mfcc','skew'].set_axis(skewColumn, axis=1)

# %%
minMfcc = gd['mfcc','min'].set_axis(minColumn, axis=1)
maxMfcc = gd['mfcc','max'].set_axis(maxColumn, axis=1)
stdMfcc = gd['mfcc','std'].set_axis(stdColumn, axis=1)
meanMfcc = gd['mfcc','mean'].set_axis(meanColumn, axis=1)
medianMfcc = gd['mfcc','median'].set_axis(medianColumn, axis=1)
skewMfcc = gd['mfcc','skew'].set_axis(skewColumn, axis=1)
# Out:
# /var/folders/gv/571nb6gs4h58lv0gw0__gy280000gn/T/ipykernel_24877/2388817679.py:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   minMfcc = gd['mfcc','min'].set_axis(minColumn, axis=1)
# /var/folders/gv/571nb6gs4h58lv0gw0__gy280000gn/T/ipykernel_24877/2388817679.py:2: PerformanceWarning: indexing past lexsort depth may impact performance.
#   maxMfcc = gd['mfcc','max'].set_axis(maxColumn, axis=1)
# /var/folders/gv/571nb6gs4h58lv0gw0__gy280000gn/T/ipykernel_24877/2388817679.py:3: PerformanceWarning: indexing past lexsort depth may impact performance.
#   stdMfcc = gd['mfcc','std'].set_axis(stdColumn, axis=1)
# /var/folders/gv/571nb6gs4h58lv0gw0__gy280000gn/T/ipykernel_24877/2388817679.py:4: PerformanceWarning: indexing past lexsort depth may impact performance.
#   meanMfcc = gd['mfcc','mean'].set_axis(meanColumn, axis=1)
# /var/folders/gv/571nb6gs4h58lv0gw0__gy280000gn/T/ipykernel_24877/2388817679.py:5: PerformanceWarning: indexing past lexsort depth may impact performance.
#   medianMfcc = gd['mfcc','median'].set_axis(medianColumn, axis=1)
# /var/folders/gv/571nb6gs4h58lv0gw0__gy280000gn/T/ipykernel_24877/2388817679.py:6: PerformanceWarning: indexing past lexsort depth may impact performance.
#   skewMfcc = gd['mfcc','skew'].set_axis(skewColumn, axis=1)

# %%
maxMfcc
# Out:
#        max_1       max_2       max_3       max_4      max_5      max_6  \
# 0  42.271564  220.498154  110.815704  150.749023  93.082695  81.462585
#
#        max_7      max_8      max_9     max_10     max_11     max_12  \
# 0  50.087471  65.633408  55.735863  51.613995  44.061829  49.848186
#
#       max_13   max_14     max_15     max_16    max_17     max_18     max_19  \
# 0  57.929108  41.2099  45.105576  37.426315  42.33815  45.392616  57.937553
#
#       max_20
# 0  46.261642

# %%
mfcc_clean = pd.concat([minMfcc, maxMfcc],axis=1)
mfcc_clean = pd.concat([mfcc_clean, stdMfcc],axis=1)
mfcc_clean = pd.concat([mfcc_clean, meanMfcc],axis=1)
mfcc_clean = pd.concat([mfcc_clean, medianMfcc],axis=1)
mfcc_clean = pd.concat([mfcc_clean, skewMfcc],axis=1)
mfcc_clean = pd.concat([mfcc_clean, kurtosisMfcc],axis=1)

# %%
mfcc_clean
# Out:
#         min_1      min_2       min_3      min_4      min_5      min_6  \
# 0 -467.796326 -41.723358 -125.653946 -49.782211 -84.821136 -61.988029
#
#        min_7      min_8      min_9     min_10  ...  kurtosis_11  kurtosis_12  \
# 0 -79.712204 -54.628189 -62.118481 -59.670609  ...     0.652802     0.518191
#
#    kurtosis_13  kurtosis_14  kurtosis_15  kurtosis_16  kurtosis_17  \
# 0     0.592404     0.757636     0.336972     0.450667     0.373149
#
#    kurtosis_18  kurtosis_19  kurtosis_20
# 0     0.291161      0.48282     0.415764
#
# [1 rows x 140 columns]

# %%
model.predict(mfcc_clean)
# Out:
# array([21])
