# %%
import pandas as pd

# %%
df = pd.read_csv("base_recommendation_data.csv",index_col=[0])

# %%
df
# Out:
#               Rock  Electronic       Pop   Hip-Hop      Folk  interest  \
# track_id
# 2         0.003852    0.005550  0.005266  0.984290  0.001042      4656
# 3         0.005080    0.005721  0.008029  0.976267  0.004902      1470
# 5         0.001798    0.011358  0.007218  0.978299  0.001327      1933
# 10        0.077985    0.412050  0.500906  0.002317  0.006742     54881
# 134       0.016695    0.003444  0.001296  0.978429  0.000135      1126
# ...            ...         ...       ...       ...       ...       ...
# 155315    0.996664    0.002313  0.000518  0.000307  0.000198       153
# 155316    0.999386    0.000134  0.000190  0.000005  0.000285       122
# 155317    0.987135    0.010368  0.000806  0.000102  0.001588       194
# 155318    0.999207    0.000713  0.000058  0.000012  0.000011       214
# 155319    0.995142    0.004130  0.000478  0.000033  0.000216       336
#
#           favorites  listens
# track_id
# 2                 2     1293
# 3                 1      514
# 5                 6     1151
# 10              178    50135
# 134               3      943
# ...             ...      ...
# 155315            1      128
# 155316            1      102
# 155317            1      165
# 155318            2      168
# 155319            0      294
#
# [32241 rows x 8 columns]

# %%
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from mlxtend.frequent_patterns import apriori, association_rules



# Interaction score
df['interaction_score'] = df[['interest', 'favorites', 'listens']].sum(axis=1)

# Genre columns
genre_cols = ['Rock', 'Electronic', 'Pop', 'Hip-Hop', 'Folk']

genre_probs = df[genre_cols].copy()
def top2_one_hot(row):
    top2 = row.nlargest(3).index
    binary = pd.Series(0, index=row.index)
    binary[top2] = 1
    return binary

df_genres_encoded = genre_probs.apply(top2_one_hot, axis=1)

# Run Apriori
frequent_items = apriori(df_genres_encoded, min_support=0.001, use_colnames=True)
rules = association_rules(frequent_items, metric='confidence', min_threshold=0.2)

# Filter tracks matching any Apriori antecedent
def matches_rules(row):
    for _, rule in rules.iterrows():
        if all(row[genre] == 1 for genre in rule['antecedents']):
            return True
    return False

filtered_track_ids = df_genres_encoded[df_genres_encoded.apply(matches_rules, axis=1)].index
filtered_df = df.loc[filtered_track_ids]

# New song genre probabilities (sample Hip-Hop heavy)
new_song = pd.read_csv("central_cee_hiphop_prob.csv",index_col=[0])

# Cosine similarity
dataset_vecs = filtered_df[genre_cols].values
interaction_scores = filtered_df['interaction_score'].values
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/mlxtend/frequent_patterns/fpcommon.py:161: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(

# %%
rules.sort_values(by='support', ascending=False)
# Out:
#               antecedents         consequents  antecedent support  \
# 0            (Electronic)              (Rock)            0.795323
# 1                  (Rock)        (Electronic)            0.858968
# 2                  (Rock)               (Pop)            0.858968
# 3                   (Pop)              (Rock)            0.773425
# 8            (Electronic)               (Pop)            0.795323
# 9                   (Pop)        (Electronic)            0.773425
# 16     (Electronic, Rock)               (Pop)            0.655749
# 21                  (Pop)  (Electronic, Rock)            0.773425
# 19           (Electronic)         (Rock, Pop)            0.795323
# 18            (Rock, Pop)        (Electronic)            0.634130
# 17      (Electronic, Pop)              (Rock)            0.573121
# 20                 (Rock)   (Electronic, Pop)            0.858968
# 11              (Hip-Hop)        (Electronic)            0.307590
# 10           (Electronic)           (Hip-Hop)            0.795323
# 7                  (Folk)              (Rock)            0.264694
# 6                  (Rock)              (Folk)            0.858968
# 14                 (Folk)               (Pop)            0.264694
# 15                  (Pop)              (Folk)            0.773425
# 5               (Hip-Hop)              (Rock)            0.307590
# 4                  (Rock)           (Hip-Hop)            0.858968
# 34                  (Pop)        (Rock, Folk)            0.773425
# 33                 (Folk)         (Rock, Pop)            0.264694
# 32            (Folk, Pop)              (Rock)            0.185323
# 31            (Rock, Pop)              (Folk)            0.634130
# 30           (Rock, Folk)               (Pop)            0.245309
# 13              (Hip-Hop)               (Pop)            0.307590
# 23  (Electronic, Hip-Hop)              (Rock)            0.270587
# 25              (Hip-Hop)  (Electronic, Rock)            0.307590
# 24        (Rock, Hip-Hop)        (Electronic)            0.182749
# 22     (Electronic, Rock)           (Hip-Hop)            0.655749
# 39              (Hip-Hop)   (Electronic, Pop)            0.307590
# 38         (Hip-Hop, Pop)        (Electronic)            0.154276
# 37      (Electronic, Pop)           (Hip-Hop)            0.573121
# 36  (Electronic, Hip-Hop)               (Pop)            0.270587
# 12                 (Folk)        (Electronic)            0.264694
# 26     (Electronic, Folk)              (Rock)            0.091188
# 28                 (Folk)  (Electronic, Rock)            0.264694
# 27           (Rock, Folk)        (Electronic)            0.245309
# 29         (Hip-Hop, Pop)              (Rock)            0.154276
# 35        (Hip-Hop, Folk)              (Rock)            0.007568
# 40        (Hip-Hop, Folk)        (Electronic)            0.007568
#
#     consequent support   support  confidence      lift  representativity  \
# 0             0.858968  0.655749    0.824507  0.959880               1.0
# 1             0.795323  0.655749    0.763414  0.959880               1.0
# 2             0.773425  0.634130    0.738247  0.954516               1.0
# 3             0.858968  0.634130    0.819899  0.954516               1.0
# 8             0.773425  0.573121    0.720615  0.931719               1.0
# 9             0.795323  0.573121    0.741017  0.931719               1.0
# 16            0.773425  0.435284    0.663797  0.858257               1.0
# 21            0.655749  0.435284    0.562801  0.858257               1.0
# 19            0.634130  0.435284    0.547305  0.863080               1.0
# 18            0.795323  0.435284    0.686427  0.863080               1.0
# 17            0.858968  0.435284    0.759498  0.884198               1.0
# 20            0.573121  0.435284    0.506752  0.884198               1.0
# 11            0.795323  0.270587    0.879702  1.106094               1.0
# 10            0.307590  0.270587    0.340223  1.106094               1.0
# 7             0.858968  0.245309    0.926764  1.078926               1.0
# 6             0.264694  0.245309    0.285585  1.078926               1.0
# 14            0.773425  0.185323    0.700141  0.905247               1.0
# 4  -0.081461    0.879534      -0.759654  0.185756  -0.136965    0.403442
# 34 -0.022053    0.963593      -0.367284  0.197019  -0.037782    0.450160
# 33 -0.000176    0.998188      -0.001424  0.229330  -0.001816    0.448941
# 32  0.008488    1.480956       0.062138  0.191275   0.324760    0.549987
# 31 -0.000176    0.999623      -0.002858  0.229330  -0.000377    0.448941
# 30 -0.022053    0.715933      -0.148411  0.197019  -0.396779    0.450160
# 13 -0.083622    0.454571      -0.439090  0.166471  -1.199878    0.350517
# 23 -0.085222    0.309291      -0.442495  0.149848  -2.233201    0.357695
# 25 -0.054498    0.660209      -0.348399  0.180367  -0.514673    0.351527
# 24  0.001860    1.052320       0.015459  0.177169   0.049719    0.495293
# 22 -0.054498    0.892836      -0.518173  0.180367  -0.120027    0.351527
# 39 -0.054640    0.706148      -0.393463  0.160258  -0.416134    0.303867
# 38 -0.001053    0.967742      -0.010127  0.146924  -0.033333    0.470726
# 37 -0.054640    0.878975      -0.512722  0.160258  -0.137689    0.303867
# 36 -0.087633    0.411628      -0.496887  0.131885  -1.429376    0.303424
# 12 -0.119329    0.312248      -0.640245  0.094122  -2.202582    0.229580
# 26 -0.005067    0.717358      -0.070722  0.083546  -0.394004    0.444345
# 28 -0.100312    0.475995      -0.650612  0.086476  -1.100864    0.194248
# 27 -0.121839    0.291832      -0.687857  0.075732  -2.426628    0.195381
# 29 -0.101346    0.176743      -0.793574  0.031741  -4.657947    0.119170
# 35 -0.002127    0.334094      -0.328927  0.005072  -1.993167    0.291480
# 40 -0.004282    0.265645      -0.712985  0.002168  -2.764423    0.115846

# %%
similarities = cosine_similarity(new_song, dataset_vecs)[0]

# Top-N Recommendations
N = 5
top_n_indices = np.argsort(similarities)[-N:][::-1]
top_n_tracks = filtered_df.iloc[top_n_indices]
top_n_scores = interaction_scores[top_n_indices]

# Evaluation
top_n_mean_interaction_score = np.mean(top_n_scores)

# Print
print("Top-N Mean Interaction Score:", top_n_mean_interaction_score)
print("\nRecommended Tracks:\n", top_n_tracks)
# Out:
# Top-N Mean Interaction Score: 8413.0
#
# Recommended Tracks:
#                Rock  Electronic       Pop   Hip-Hop      Folk  interest  \
# track_id
# 9854      0.364746    0.277586  0.156572  0.130872  0.070225       703
# 128709    0.282202    0.280077  0.158949  0.246961  0.031811      9312
# 64995     0.263233    0.200057  0.158836  0.282118  0.095756     14001
# 83229     0.307430    0.163581  0.194597  0.228911  0.105481       517
# 129234    0.373601    0.279812  0.162009  0.167174  0.017404      1852
#
#           favorites  listens  interaction_score
# track_id
# 9854              2      292                997
# 128709            7     4152              13471
# 64995             8     9110              23119
# 83229             0      438                955
# 129234            0     1671               3523
