# %%
import pandas as pd

# %%
track_genre_features = pd.read_csv("../Important Data/track_genre_feature.csv",header=[0,1,2],index_col=0)

# %%
track_genre_features.columns = pd.MultiIndex.from_tuples([('','','genre_top')]+track_genre_features.columns.to_list()[1:])

# %%
track_genre_features
# Out:
#                    chroma_cens                                          \
#                       kurtosis
#          genre_top          01        02        03        04        05
# track_id
# 2          Hip-Hop    7.180653  5.230309  0.249321  1.347620  1.482478
# 3          Hip-Hop    1.888963  0.760539  0.345297  2.295201  1.654031
# 5          Hip-Hop    0.527563 -0.077654 -0.279610  0.685883  1.937570
# 10             Pop    3.702245 -0.291193  2.196742 -0.234449  1.367364
# 20             NaN   -0.193837 -0.198527  0.201546  0.258556  0.775204
# ...            ...         ...       ...       ...       ...       ...
# 155316        Rock   -0.490129  0.463834  2.321970 -0.084352  1.662914
# 155317        Rock   -0.461559 -0.229601 -0.496632 -0.422033  0.130612
# 155318        Rock    0.552473 -0.110498 -0.532014  0.263131 -0.224011
# 155319        Rock   -0.176901  0.187208 -0.050664  0.368843  0.066005
# 155320         NaN    0.489665  1.862421  0.854461 -0.103666 -0.249835
#
# ...

# %%
top5_selected_genre_features = track_genre_features[track_genre_features['','','genre_top'].isin(["Rock","Electronic","Pop","Hip-Hop","Folk"])]

# %%
top5_selected_genre_features.to_csv("top5_selected_genre_features.csv")

# %%
top5_selected_genre_features.to_csv("optimized_model_data.csv")
